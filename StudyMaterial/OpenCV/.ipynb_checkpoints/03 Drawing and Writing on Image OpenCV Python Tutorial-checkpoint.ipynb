# %% [markdown]
# Source: https://pythonprogramming.net/drawing-writing-python-opencv-tutorial/?completed=/loading-video-python-opencv-tutorial/

# %% [markdown]
# https://youtu.be/U6uIrq2eh_o?list=PLQVvvaa0QuDdttJXlLtAJxJetJcqmqlQq

# %% [markdown]
# In this OpenCV with Python tutorial, we're going to be covering how to draw various shapes on your images and videos. It's fairly common to want to mark detected objects in some way, so we the humans can easily see if our programs are working as we might hope. An example of this would be one of the images shown before:
#
# ![image.png](attachment:11ea3b20-6b02-45b1-828a-7a7097fa0b31.png)

# %% [markdown]
# For this temporary example, I will use the following image:
#
# ![image.png](attachment:684ac41d-7d38-43d1-b6e5-126e4644b936.png)

# %% [markdown]
# You are encourage to use your own image. As usual, our starting code can be something like:

# %% [raw]
# import numpy as np
# import cv2
#
# img = cv2.imread('Source Data/watch.jpg',cv2.IMREAD_COLOR)

# %% [markdown]
# Next, we can start drawing like:

# %% [raw]
# cv2.line(img,(0,0),(150,150),(255,255,255),15)
#
# cv2.imshow('image',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# The cv2.line() takes the following parameters: where, start coordinates, end coordinates, color (bgr), line thickness.
#
# The result here:

# %%
import numpy as np
import cv2

img = cv2.imread('Source Data/watch.jpg',cv2.IMREAD_COLOR)
cv2.line(img,(0,0),(150,150),(255,255,255),15)

cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:bd38ef1f-d4b2-487d-ab0c-1aeb8920e065.png)

# %% [markdown]
# Alright, cool, let's get absurd with some more shapes. Next up, a rectangle:

# %% [raw]
# cv2.rectangle(img,(15,25),(200,150),(0,0,255),15)

# %% [markdown]
# The parameters here are the image, the top left coordinate, bottom right coordinate, color, and line thickness.
#
# How about a circle?

# %% [raw]
# cv2.circle(img,(100,63), 55, (0,255,0), -1)

# %% [markdown]
# The parameters here are the image/frame, the center of the circle, the radius, color, and then thickness. Notice we have a -1 for thickness. This means the object will actually be willed in, so we will get a filled in circle.
#
# Lines, rectangles, and circles are cool and all, but what if we want a pentagon, or octagon, or octdecagon?! No problem!

# %% [raw]
# pts = np.array([[10,5],[20,30],[70,20],[50,10]], np.int32)
# # OpenCV documentation had this code, which reshapes the array to a 1 x 2. I did not
# # find this necessary, but you may:
# #pts = pts.reshape((-1,1,2))
# cv2.polylines(img, [pts], True, (0,255,255), 3)
