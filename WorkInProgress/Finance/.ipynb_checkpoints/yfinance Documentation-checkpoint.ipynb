# %%
## https://pypi.org/project/yfinance/

# %%
import yfinance as yf

# %%
msft = yf.Ticker("MSFT")

# %%
# get stock info
msft.info
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9660\1383692640.py in <module>
#       1 # get stock info
# ----> 2 msft.info
#
# ~\anaconda3\lib\site-packages\yfinance\ticker.py in info(self)
#     136     @property
#     137     def info(self) -> dict:
# --> 138         return self.get_info()
#     139
#     140     @property
#
# ~\anaconda3\lib\site-packages\yfinance\base.py in get_info(self, proxy)
#    1473     def get_info(self, proxy=None) -> dict:
#    1474         self._quote.proxy = proxy
# -> 1475         data = self._quote.info
#    1476         return data
#    1477
#
# ~\anaconda3\lib\site-packages\yfinance\scrapers\quote.py in info(self)
#      96         if self._info is None:
#      97             # self._scrape(self.proxy)  # decrypt broken
# ---> 98             self._fetch(self.proxy)
#      99
#     100             self._fetch_complementary(self.proxy)
#
# ~\anaconda3\lib\site-packages\yfinance\scrapers\quote.py in _fetch(self, proxy)
#     246         self._already_fetched = True
#     247
# --> 248         result = self._data.get_raw_json(
#     249             _BASIC_URL_, params={"formatted": "true", "lang": "en-US", "symbols": self._data.ticker}, proxy=proxy
#     250         )
#
# ~\anaconda3\lib\site-packages\yfinance\data.py in get_raw_json(self, url, user_agent_headers, params, proxy, timeout)
#     207     def get_raw_json(self, url, user_agent_headers=None, params=None, proxy=None, timeout=30):
#     208         response = self.get(url, user_agent_headers=user_agent_headers, params=params, proxy=proxy, timeout=timeout)
# --> 209         response.raise_for_status()
#     210         return response.json()
#     211
#
# ~\anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#    1019
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#    1023     def close(self):
#
# HTTPError: 401 Client Error: Unauthorized for url: https://query1.finance.yahoo.com/v7/finance/quote?formatted=true&lang=en-US&symbols=MSFT

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# get historical market data
hist = msft.history(period="max")

# %%
hist.tail(5)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-12-19 00:00:00-05:00  244.860001  245.210007  238.710007  240.449997
# 2022-12-20 00:00:00-05:00  239.399994  242.910004  238.419998  241.800003
# 2022-12-21 00:00:00-05:00  241.690002  245.619995  240.110001  244.429993
# 2022-12-22 00:00:00-05:00  241.259995  241.990005  233.869995  238.190002
# 2022-12-23 00:00:00-05:00  236.110001  238.869995  233.940002  238.729996
#
#                              Volume  Dividends  Stock Splits
# Date
# 2022-12-19 00:00:00-05:00  29696400        0.0           0.0
# 2022-12-20 00:00:00-05:00  25150800        0.0           0.0
# 2022-12-21 00:00:00-05:00  23690600        0.0           0.0
# 2022-12-22 00:00:00-05:00  28651700        0.0           0.0
# 2022-12-23 00:00:00-05:00  21203200        0.0           0.0

# %%
# show meta information about the history (requires history() to be called first)
msft.history_metadata
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-22021ab06b4d> in <module>()
#       1 # show meta information about the history (requires history() to be called first)
# ----> 2 msft.history_metadata
#
# AttributeError: 'Ticker' object has no attribute 'history_metadata'

# %%
# show actions (dividends, splits, capital gains)
msft.actions.tail(5)
# Out:
#                            Dividends  Stock Splits
# Date
# 2021-11-17 00:00:00-05:00       0.62           0.0
# 2022-02-16 00:00:00-05:00       0.62           0.0
# 2022-05-18 00:00:00-04:00       0.62           0.0
# 2022-08-17 00:00:00-04:00       0.62           0.0
# 2022-11-16 00:00:00-05:00       0.68           0.0

# %%
# show dividends
msft.dividends.tail(5)
# Out:
# Date
# 2021-11-17 00:00:00-05:00    0.62
# 2022-02-16 00:00:00-05:00    0.62
# 2022-05-18 00:00:00-04:00    0.62
# 2022-08-17 00:00:00-04:00    0.62
# 2022-11-16 00:00:00-05:00    0.68
# Name: Dividends, dtype: float64

# %%
# show splits
msft.splits.tail(5)
# Out:
# Date
# 1994-05-23 00:00:00-04:00    2.0
# 1996-12-09 00:00:00-05:00    2.0
# 1998-02-23 00:00:00-05:00    2.0
# 1999-03-29 00:00:00-05:00    2.0
# 2003-02-18 00:00:00-05:00    2.0
# Name: Stock Splits, dtype: float64

# %%
# show capital gains (for mutual funds & etfs)
msft.capital_gains.tail
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-f566527332f7> in <module>()
#       1 # show capital gains (for mutual funds & etfs)
# ----> 2 msft.capital_gains.tail
#
# AttributeError: 'Ticker' object has no attribute 'capital_gains'

# %%
# show share count
msft.shares

# %%
# show financials:
# - income statement
msft.income_stmt
msft.quarterly_income_stmt
# - balance sheet
msft.balance_sheet
msft.quarterly_balance_sheet
# - cash flow statement
msft.cashflow
msft.quarterly_cashflow
# see `Ticker.get_income_stmt()` for more options
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-e25fb04d4a8c> in <module>()
#       1 # show financials:
#       2 # - income statement
# ----> 3 msft.income_stmt
#       4 msft.quarterly_income_stmt
#       5 # - balance sheet
#
# AttributeError: 'Ticker' object has no attribute 'income_stmt'

# %%
# show major holders
msft.major_holders
# Out:
#         0                                      1
# 0   0.06%        % of Shares Held by All Insider
# 1  72.30%       % of Shares Held by Institutions
# 2  72.34%        % of Float Held by Institutions
# 3    5977  Number of Institutions Holding Shares

# %%
# show institutional holders
msft.institutional_holders
# Out:
#                             Holder     Shares Date Reported   % Out  \
# 0       Vanguard Group, Inc. (The)  634238715    2022-09-29  0.0851
# 1                   Blackrock Inc.  518843676    2022-09-29  0.0696
# 2         State Street Corporation  295509547    2022-09-29  0.0396
# 3                         FMR, LLC  204088395    2022-09-29  0.0274
# 4    Price (T.Rowe) Associates Inc  171346779    2022-09-29  0.0230
# 5    Geode Capital Management, LLC  139462260    2022-09-29  0.0187
# 6                   Morgan Stanley  104765804    2022-09-29  0.0141
# 7          Capital World Investors   97528997    2022-09-29  0.0131
# 8        JP Morgan Chase & Company   92745324    2022-09-29  0.0124
# 9  Capital International Investors   84987239    2022-09-29  0.0114
#
#           Value
# 0  151411805722
# 1  123863548554
# 2   70546992892
# 3   48722021666
# 4   40905615818
# 5   33293824733
# 6   25010739941
# 7   23283097037
# 8   22141090802
# 9   20289003203

# %%
# show mutualfund holders
msft.mutualfund_holders
# Out:
#                                               Holder     Shares Date Reported  \
# 0             Vanguard Total Stock Market Index Fund  222313847    2022-09-29
# 1                            Vanguard 500 Index Fund  169062762    2022-09-29
# 2                             SPDR S&P 500 ETF Trust   82389656    2022-11-29
# 3                            Fidelity 500 Index Fund   80929699    2022-10-30
# 4                           iShares Core S&P 500 ETF   67412361    2022-10-30
# 5        Invesco ETF Tr-Invesco QQQ Tr, Series 1 ETF   65747097    2022-11-29
# 6                         Vanguard Growth Index Fund   61426549    2022-09-29
# 7  Vanguard Institutional Index Fund-Institutiona...   54149972    2022-09-29
# 8                         Growth Fund Of America Inc   49038474    2022-09-29
# 9                 Select Sector SPDR Fund-Technology   35233656    2022-11-29
#
#     % Out        Value
# 0  0.0298  53072983744
# 1  0.0227  40360352449
# 2  0.0111  19668882224
# 3  0.0109  19320346696
# 4  0.0090  16093352653
# 5  0.0088  15695804185
# 6  0.0082  14664359780
# 7  0.0073  12927222584
# 8  0.0066  11706954688
# 9  0.0047   8411330546

# %%
# show earnings
msft.earnings
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
msft.quarterly_earnings
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
# show sustainability
msft.sustainability

# %%
# show analysts recommendations
msft.recommendations

# %%
msft.recommendations_summary
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-eddba9ae0667> in <module>()
# ----> 1 msft.recommendations_summary
#
# AttributeError: 'Ticker' object has no attribute 'recommendations_summary'

# %%
# show analysts other work
msft.analyst_price_target
msft.revenue_forecasts
msft.earnings_forecasts
msft.earnings_trend
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-fe926dd4742f> in <module>()
#       1 # show analysts other work
# ----> 2 msft.analyst_price_target
#       3 msft.revenue_forecasts
#       4 msft.earnings_forecasts
#       5 msft.earnings_trend
#
# AttributeError: 'Ticker' object has no attribute 'analyst_price_target'

# %%
# show next event (earnings, etc)
msft.calendar

# %%
# Show future and historic earnings dates, returns at most next 4 quarters and last 8 quarters by default. 
# Note: If more are needed use msft.get_earnings_dates(limit=XX) with increased limit argument.
msft.earnings_dates
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-f4a9db42d07d> in <module>()
#       1 # Show future and historic earnings dates, returns at most next 4 quarters and last 8 quarters by default.
#       2 # Note: If more are needed use msft.get_earnings_dates(limit=XX) with increased limit argument.
# ----> 3 msft.earnings_dates
#
# ~\Anaconda3\lib\site-packages\yfinance\ticker.py in earnings_dates(self)
#     219     @property
#     220     def earnings_dates(self):
# --> 221         return self.get_earnings_dates()
#
# ~\Anaconda3\lib\site-packages\yfinance\base.py in get_earnings_dates(self, proxy)
#     977         # - instead of attempting decoding of ambiguous timezone abbreviation, just use 'info':
#     978         dates[cn] = dates[cn].dt.tz_localize(
# --> 979             tz=self.info["exchangeTimezoneName"])
#     980
#     981         dates = dates.set_index("Earnings Date")
#
# KeyError: 'exchangeTimezoneName'

# %%
# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
msft.isin
# Out:
# 'US5949181045'

# %%
# show options expirations
msft.options
# Out:
# ('2022-12-30',
#  '2023-01-06',
#  '2023-01-13',
#  '2023-01-20',
#  '2023-01-27',
#  '2023-02-03',
#  '2023-02-17',
#  '2023-03-17',
#  '2023-04-21',
#  '2023-06-16',
#  '2023-07-21',
#  '2023-09-15',
#  '2024-01-19',
#  '2024-06-21',
#  '2025-01-17')

# %%
# show news
msft.news
# Out:
# [{'link': 'https://finance.yahoo.com/m/6fa55a71-2a5c-3c7c-852c-8da7ea2d36ba/best-stocks-to-buy-and-watch.html',
#   'providerPublishTime': 1672068029,
#   'publisher': "Investor's Business Daily",
#   'relatedTickers': ['MSFT'],
#   'thumbnail': {'resolutions': [{'height': 563,
#      'tag': 'original',
#      'url': 'https://s.yimg.com/uu/api/res/1.2/YT.cwQLk4qEhyB3Bo5nmvw--~B/aD01NjM7dz0xMDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/2c5e2f23a6ddb52972e092492f32a3c0',
#      'width': 1000},
#     {'height': 140,
#      'tag': '140x140',
#      'url': 'https://s.yimg.com/uu/api/res/1.2/GA7cp4_u3IS0F6Kabd.tkw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/2c5e2f23a6ddb52972e092492f32a3c0',
#      'width': 140}]},
#   'title': 'Best Stocks To Buy And Watch Now: 5 Top Tech Stocks For December',
#   'type': 'STORY',
#   'uuid': '6fa55a71-2a5c-3c7c-852c-8da7ea2d36ba'},
#  {'link': 'https://finance.yahoo.com/m/85203998-15c9-3b18-97dc-5778a35f68ad/these-6-stocks-are-why-warren.html',
#   'providerPublishTime': 1672052220,
#   'publisher': 'Motley Fool',
#   'relatedTickers': ['BRK-B', '^GSPC', 'KHC', 'MSFT', 'KO'],
#   'thumbnail': {'resolutions': [{'height': 1365,
#      'tag': 'original',
#      'url': 'https://s.yimg.com/uu/api/res/1.2/HE9iMyv88Gie0JrdfpAvHw--~B/aD0xMzY1O3c9MjA0ODthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/motleyfool.com/773d668587b22b0881957c208676aaf4',
#      'width': 2048},
#     {'height': 140,
#      'tag': '140x140',
#      'url': 'https://s.yimg.com/uu/api/res/1.2/uUz.GuyGHlCWN7anMN1enw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/773d668587b22b0881957c208676aaf4',
#      'width': 140}]},
#   'title': 'These 6 Stocks Are Why Warren Buffett Beat the Market In 2022',
#   'type': 'STORY',
#   'uuid': '85203998-15c9-3b18-97dc-5778a35f68ad'},
#  {'link': 'https://finance.yahoo.com/news/tipranks-perfect-10-list-2-093000355.html',
#   'providerPublishTime': 1671960600,
#   'publisher': 'TipRanks',
#   'relatedTickers': ['GOOGL', 'MSFT'],
#   'thumbnail': {'resolutions': [{'height': 463,
#      'tag': 'original',
#      'url': 'https://s.yimg.com/uu/api/res/1.2/wXlZW_DjLEMS2fl.VZRsHg--~B/aD00NjM7dz04NTI7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/tipranks_452/33a83d81bf1d6a6ddf907637fb0cd623',
#      'width': 852},
#     {'height': 140,
#      'tag': '140x140',
#      'url': 'https://s.yimg.com/uu/api/res/1.2/nOWMzc1s1ja6TNbaP5MJZA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/tipranks_452/33a83d81bf1d6a6ddf907637fb0cd623',
#      'width': 140}]},
#   'title': 'TipRanks ‘Perfect 10’ List: These 2 Stock Giants Look Compelling at Current Levels',
#   'type': 'STORY',
#   'uuid': '2144fac8-f62f-37a7-83cd-03b8ac010423'},
#  {'link': 'https://finance.yahoo.com/m/2748db21-e293-3769-8d57-c2983cf614e4/this-company-has-wiped-out.html',
#   'providerPublishTime': 1671902880,
#   'publisher': 'MarketWatch',
#   'relatedTickers': ['TSLA', 'AMZN', 'MSFT', '^GSPC', 'AAPL', 'NVDA'],
#   'thumbnail': {'resolutions': [{'height': 640,
#      'tag': 'original',
#      'url': 'https://s.yimg.com/uu/api/res/1.2/dKxNeo.5duNLe7GKHPc4OA--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/marketwatch.com/84b9dbc54c0cb58a3d2720b9527ac685',
#      'width': 1280},
#     {'height': 140,
#      'tag': '140x140',
#      'url': 'https://s.yimg.com/uu/api/res/1.2/IiOp_VqL3JImjYyaHBafCw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/marketwatch.com/84b9dbc54c0cb58a3d2720b9527ac685',
#      'width': 140}]},
#   'title': 'This company has wiped out more investor wealth in 2022 than Tesla',
#   'type': 'STORY',
#   'uuid': '2748db21-e293-3769-8d57-c2983cf614e4'},
#  {'link': 'https://finance.yahoo.com/news/microsoft-nasdaq-msft-knows-allocate-140021929.html',
#   'providerPublishTime': 1671890421,
#   'publisher': 'Simply Wall St.',
#   'relatedTickers': ['MSFT'],
#   'thumbnail': {'resolutions': [{'height': 432,
#      'tag': 'original',
#      'url': 'https://s.yimg.com/uu/api/res/1.2/eFZZVJx6QdqQsl5Qimg4Rw--~B/aD00MzI7dz0xMTk0O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/simply_wall_st__316/a5d5a89dd6ab73bc7694c99b9023ec2d',
#      'width': 1194},
#     {'height': 140,
#      'tag': '140x140',
#      'url': 'https://s.yimg.com/uu/api/res/1.2/5Fy.yFFq_J2cr_4EvCbCFw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/simply_wall_st__316/a5d5a89dd6ab73bc7694c99b9023ec2d',
#      'width': 140}]},
#   'title': 'Microsoft (NASDAQ:MSFT) Knows How To Allocate Capital Effectively',
#   'type': 'STORY',
#   'uuid': '1a7c480d-2e43-3bab-af53-a087c441c4d8'},
#  {'link': 'https://finance.yahoo.com/m/af8e96e1-0c6a-3323-9e1c-21523ad25c56/these-stocks-moved-today%3A.html',
#   'providerPublishTime': 1671830460,
#   'publisher': 'Barrons.com',
#   'relatedTickers': ['MSFT', 'TSLA', 'APE'],
#   'thumbnail': {'resolutions': [{'height': 640,
#      'tag': 'original',
#      'url': 'https://s.yimg.com/uu/api/res/1.2/PokQ0BI6e_jtQyhmWR2PKA--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/Barrons.com/476e73930351b47037956b57bbbb15e5',
#      'width': 1280},
#     {'height': 140,
#      'tag': '140x140',
#      'url': 'https://s.yimg.com/uu/api/res/1.2/JbYk6TtjU0.pe1_YeWc8hA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/Barrons.com/476e73930351b47037956b57bbbb15e5',
#      'width': 140}]},
#   'title': 'These Stocks Moved Today: Tesla, AMC, Energy Stocks, and More',
#   'type': 'STORY',
#   'uuid': 'af8e96e1-0c6a-3323-9e1c-21523ad25c56'},
#  {'link': 'https://finance.yahoo.com/m/0033e4cf-7345-3076-aa5e-b25cecf56df8/apple-hubs-in-india%2C-vietnam.html',
#   'providerPublishTime': 1671824789,
#   'publisher': "Investor's Business Daily",
#   'relatedTickers': ['AAPL', 'INTC', 'MSFT', 'NVDA', 'GOOGL'],
#   'thumbnail': {'resolutions': [{'height': 533,
#      'tag': 'original',
#      'url': 'https://s.yimg.com/uu/api/res/1.2/Jt_sVB5KWSxnEBLyzWXmRw--~B/aD01MzM7dz05NDU7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/ibd.com/0c88bfd6d2eb7aa7f743bed61b057ce8',
#      'width': 945},
#     {'height': 140,
#      'tag': '140x140',
#      'url': 'https://s.yimg.com/uu/api/res/1.2/BQChzmM3xnJJJEs2MLrSqg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/0c88bfd6d2eb7aa7f743bed61b057ce8',
#      'width': 140}]},
#   'title': 'Apple Hubs In India, Vietnam Next Year; China Exodus By 2025. Are Beaten Down Tech Stocks A Buy Now?',
#   'type': 'STORY',
#   'uuid': '0033e4cf-7345-3076-aa5e-b25cecf56df8'},
#  {'link': 'https://finance.yahoo.com/video/microsoft-activision-push-ftc-acquisition-170600354.html',
#   'providerPublishTime': 1671815160,
#   'publisher': 'Yahoo Finance Video',
#   'relatedTickers': ['ATVI', 'MSFT'],
#   'thumbnail': {'resolutions': [{'height': 720,
#      'tag': 'original',
#      'url': 'https://s.yimg.com/uu/api/res/1.2/ccrAI1LcB1c6ycGUSAg0Qw--~B/aD03MjA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/os/creatr-uploaded-images/2022-12/017b3700-82e4-11ed-9fdf-4571b8a8c5da',
#      'width': 1280},
#     {'height': 140,
#      'tag': '140x140',
#      'url': 'https://s.yimg.com/uu/api/res/1.2/9jhNZdpTyMll4BWInL978g--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/os/creatr-uploaded-images/2022-12/017b3700-82e4-11ed-9fdf-4571b8a8c5da',
#      'width': 140}]},
#   'title': 'Microsoft, Activision push the FTC for acquisition approval',
#   'type': 'VIDEO',
#   'uuid': '327dfd3d-e76f-3b15-b419-4ba95cc4c854'}]

# %%
# get option chain for specific expiration
opt = msft.option_chain('YYYY-MM-DD')
# data available via: opt.calls, opt.puts
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-8094f0eede80> in <module>()
#       1 # get option chain for specific expiration
# ----> 2 opt = msft.option_chain('YYYY-MM-DD')
#       3 # data available via: opt.calls, opt.puts
#
# ~\Anaconda3\lib\site-packages\yfinance\ticker.py in option_chain(self, date, proxy, tz)
#     100                     "Expiration `%s` cannot be found. "
#     101                     "Available expiration are: [%s]" % (
# --> 102                         date, ', '.join(self._expirations)))
#     103             date = self._expirations[date]
#     104             options = self._download_options(date, proxy=proxy)
#
# ValueError: Expiration `YYYY-MM-DD` cannot be found. Available expiration are: [2022-12-30, 2023-01-06, 2023-01-13, 2023-01-20, 2023-01-27, 2023-02-03, 2023-02-17, 2023-03-17, 2023-04-21, 2023-06-16, 2023-07-21, 2023-09-15, 2024-01-19, 2024-06-21, 2025-01-17]

# %% [markdown]
# ### Sandbox

# %%
type(msft.news)
# Out:
# list

# %%
type(msft.news)
# Out:
# list

# %%
type(msft.news[0])
# Out:
# dict

# %%
msft.news[0]
# Out:
# {'link': 'https://finance.yahoo.com/m/6fa55a71-2a5c-3c7c-852c-8da7ea2d36ba/best-stocks-to-buy-and-watch.html',
#  'providerPublishTime': 1672068029,
#  'publisher': "Investor's Business Daily",
#  'relatedTickers': ['MSFT'],
#  'thumbnail': {'resolutions': [{'height': 563,
#     'tag': 'original',
#     'url': 'https://s.yimg.com/uu/api/res/1.2/YT.cwQLk4qEhyB3Bo5nmvw--~B/aD01NjM7dz0xMDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/2c5e2f23a6ddb52972e092492f32a3c0',
#     'width': 1000},
#    {'height': 140,
#     'tag': '140x140',
#     'url': 'https://s.yimg.com/uu/api/res/1.2/GA7cp4_u3IS0F6Kabd.tkw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/2c5e2f23a6ddb52972e092492f32a3c0',
#     'width': 140}]},
#  'title': 'Best Stocks To Buy And Watch Now: 5 Top Tech Stocks For December',
#  'type': 'STORY',
#  'uuid': '6fa55a71-2a5c-3c7c-852c-8da7ea2d36ba'}

# %%
##Since the individual items are dictionaries, you can call it:
msft.news[0]["title"]
# Out:
# 'Best Stocks To Buy And Watch Now: 5 Top Tech Stocks For December'

# %%
for i in range(0, len(msft.news)):
    print(msft.news[i]["title"])
# Out:
# Best Stocks To Buy And Watch Now: 5 Top Tech Stocks For December
# These 6 Stocks Are Why Warren Buffett Beat the Market In 2022
# TipRanks ‘Perfect 10’ List: These 2 Stock Giants Look Compelling at Current Levels
# This company has wiped out more investor wealth in 2022 than Tesla
# Microsoft (NASDAQ:MSFT) Knows How To Allocate Capital Effectively
# These Stocks Moved Today: Tesla, AMC, Energy Stocks, and More
# Apple Hubs In India, Vietnam Next Year; China Exodus By 2025. Are Beaten Down Tech Stocks A Buy Now?
# Microsoft, Activision push the FTC for acquisition approval
